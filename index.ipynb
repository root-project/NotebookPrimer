# %% [markdown]
# <section id="cd-timeline">
# <!-- TITLE!!! -->
# <div style="text-align:center; margin-bottom:2em;">
# <h1>The ROOT Primer</h1>
# </div>
#
# <!-- LEFT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-content left" style="possition:relative; width:45%; float:left; border-right:4px solid #1ED4E5; margin-left:5%; padding-right: 3%;text-align:right;">
# <h2><span  style="margin-right:-13%;">1 Motivation and Introduction</span></h2>
# <p style="text-align:right;">Why did we create the ROOT Primer? What will you learn from reading it? The first chapter will answer these questions for you.</p>
# <a href="notebooks/1-Motivation-and-Introduction.ipynb" class="cd-read-more">Take me there! </a>
# </div><!-- cd-timeline-content -->
# <div id="cd-timeline-image" style="position:relative;width:47.5%;float:left;padding-left:5%;clear:right;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;left:0px;margin-left:-5%; ">
# </div><!-- cd-timeline-image -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- RIGHT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-image" style="position:relative; width:50%; float:left;padding-right:5%;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;right:0px;margin-right:-5%;z-index:100;">
# </div><!-- cd-timeline-image -->
# <div id="cd-timeline-content left" style="possition:relative; width:50.4%; float:right; border-left:4px solid #1ED4E5; margin-left:-5%; padding:0% 3%;z-index:1;">
# <h2>2 ROOT Basics</h2>
# <p>Let's dive right in. In the second chapter you will learn all the necessary commands to create your first plots. Edit the code provided and re-run the notebook in order to get new results. Additionally you can manipulate the plots o your screen and save them as an image.<a href="notebooks/2-ROOT-Basics.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter2.png" alt="Chapter 2" style="margin:auto; width:300px;"></a>
# </p>
# <a href="notebooks/2-ROOT-Basics.ipynb" class="cd-read-more">Take me there!</a></div><!-- cd-timeline-content -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- LEFT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-content left" style="possition:relative; width:45%; float:left; border-right:4px solid #1ED4E5; margin-left:5%; padding-right: 3%;text-align:right;">
# <h2><span  style="margin-right:-13%;">3 ROOT Macros</span></h2>
# <p>By now you know enough to start using ROOT and there is more. In chapter three you will master how to create ROOT macros and re-use your code with different data sets.<a href="notebooks/3-ROOT-Macros.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter3.png" alt="Chapter 3" style="margin:auto; width:300px;"></a></p>
# <a href="notebooks/3-ROOT-Macros.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# <div id="cd-timeline-image" style="position:relative;width:47.5%;float:left;padding-left:5%;clear:right;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;left:0px;margin-left:-5%; ">
# </div><!-- cd-timeline-image -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- RIGHT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-image" style="position:relative; width:50%; float:left;padding-right:5%;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;right:0px;margin-right:-5%;z-index:100;">
# </div><!-- cd-timeline-image -->
# <div id="cd-timeline-content left" style="possition:relative; width:50.4%; float:right; border-left:4px solid #1ED4E5; margin-left:-5%; padding:0% 3%;z-index:1;">
# <h2>4 Graphs</h2>
# <p>
# <a href="notebooks/4-Graphs.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter4.png" alt="Chapter 4" style="margin:auto; width:300px;"></a>
# Now it gets impressive! This chapter will show you how to exploit ROOT functionalities to create complicated graphs with errors like this one.</p>
# <a href="notebooks/4-Graphs.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- LEFT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-content left" style="possition:relative; width:45%; float:left; border-right:4px solid #1ED4E5; margin-left:5%; padding-right: 3%;text-align:right;">
# <h2><span  style="margin-right:-13%;">5 Histograms</span></h2>
# <p>Histograms are powerful tools for measurements visualisation and data reduction. In this chapter will find out how to create ni- and bi- dimensional histograms with ROOT.
# <a href="notebooks/5-Histograms.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter5.png" alt="Chapter 5" style="margin:auto; width:300px;"></a></p>
# <a href="notebooks/5-Histograms.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# <div id="cd-timeline-image" style="position:relative;width:47.5%;float:left;padding-left:5%;clear:right;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;left:0px;margin-left:-5%; ">
# </div><!-- cd-timeline-image -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- RIGHT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-image" style="position:relative; width:50%; float:left;padding-right:5%;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;right:0px;margin-right:-5%;z-index:100;">
# </div><!-- cd-timeline-image -->
# <div id="cd-timeline-content left" style="possition:relative; width:50.4%; float:right; border-left:4px solid #1ED4E5; margin-left:-5%; padding:0% 3%;z-index:1;">
# <h2>6 Functions and Parameter Estimation</h2>
# <p>Information to be added soon.<a href="notebooks/6-Functions-and-Parameter-Estimation.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter6.png" alt="Chapter 6" style="margin:auto; width:350px;"></a></p>
# <a href="notebooks/6-Functions-and-Parameter-Estimation.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- LEFT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-content left" style="possition:relative; width:45%; float:left; border-right:4px solid #1ED4E5; margin-left:5%; padding-right: 3%;text-align:right;">
# <h2><span  style="margin-right:-13%;">7 File IO and Parallel Analysis</span></h2>
# <p><a href="notebooks/7-File-IO-and-Parallel-Analysis.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter7.png" alt="Chapter 7" style="margin:auto; width:350px;"></a>You created beautiful and informative graphs in all of the previous sections, now it is time to store them!
# </p>
# <a href="notebooks/7-File-IO-and-Parallel-Analysis.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# <div id="cd-timeline-image" style="position:relative;width:47.5%;float:left;padding-left:5%;clear:right;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;left:0px;margin-left:-5%; ">
# </div><!-- cd-timeline-image -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- RIGHT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-image" style="position:relative; width:50%; float:left;padding-right:5%;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;right:0px;margin-right:-5%;z-index:100;">
# </div><!-- cd-timeline-image -->
# <div id="cd-timeline-content left" style="possition:relative; width:50.4%; float:right; border-left:4px solid #1ED4E5; margin-left:-5%; padding:0% 3%;z-index:1;">
# <h2>8 ROOT in Python</h2>
# <p>Maybe you are more comfortable with Python than with C++? ROOT offers a set of bindings called PyROOT, in order to interface to Python. Go through this chapter and learn how to use it. <a href="notebooks/8-ROOT-in-Python.ipynb" class="cd-read-more"><img src="notebooks/images/Chapter8.png" alt="Chapter 6" style="margin:auto; width:350px;"></a></p>
# <a href="notebooks/8-ROOT-in-Python.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# <!-- LEFT BLOCK!!!! -->
# <div class="cd-timeline-block" style="clear:both;">
# <div class="cd-timeline-block-inner" style="possition:relative;">
# <div id="cd-timeline-content left" style="possition:relative; width:45%; float:left; border-right:4px solid #1ED4E5; margin-left:5%; padding-right: 3%;text-align:right;">
# <h2><span  style="margin-right:-13%;">9 Concluding Remarks</span></h2>
# <p>This tutorial came to an end. Read this chapter to get more resources and documentation about ROOT. </p>
# <a href="notebooks/9-Concluding-Remarks.ipynb" class="cd-read-more">Take me there!</a>
# </div><!-- cd-timeline-content -->
# <div id="cd-timeline-image" style="position:relative;width:47.5%;float:left;padding-left:5%;clear:right;">
# <img src="notebooks/images/rootlogo.png" alt="Mountain View" style="width:10%;position:absolute;left:0px;margin-left:-5%; ">
# </div><!-- cd-timeline-image -->
# </div><!-- cd-timeline-block-inner -->
# </div><!-- cd-timeline-block -->
#
# </section>
